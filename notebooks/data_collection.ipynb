# %%
pip install pybaseball pandas numpy matplotlib seaborn scikit-learn sqlalchemy psycopg2-binary jupyter notebook
# Out:
# Requirement already satisfied: pybaseball in c:\users\susov\anaconda3\lib\site-packages (2.2.7)
# Requirement already satisfied: pandas in c:\users\susov\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\susov\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\susov\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\susov\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\susov\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: sqlalchemy in c:\users\susov\anaconda3\lib\site-packages (2.0.34)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.10-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: jupyter in c:\users\susov\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: notebook in c:\users\susov\anaconda3\lib\site-packages (7.2.2)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in c:\users\susov\anaconda3\lib\site-packages (from pybaseball) (4.12.3)
# Requirement already satisfied: requests>=2.18.1 in c:\users\susov\anaconda3\lib\site-packages (from pybaseball) (2.32.3)
# Requirement already satisfied: lxml>=4.2.1 in c:\users\susov\anaconda3\lib\site-packages (from pybaseball) (5.2.1)
# Requirement already satisfied: pyarrow>=1.0.1 in c:\users\susov\anaconda3\lib\site-packages (from pybaseball) (16.1.0)
# Requirement already satisfied: pygithub>=1.51 in c:\users\susov\anaconda3\lib\site-packages (from pybaseball) (2.6.1)
# Requirement already satisfied: scipy>=1.4.0 in c:\users\susov\anaconda3\lib\site-packages (from pybaseball) (1.13.1)
# Requirement already satisfied: tqdm>=4.50.0 in c:\users\susov\anaconda3\lib\site-packages (from pybaseball) (4.66.5)
# Requirement already satisfied: attrs>=20.3.0 in c:\users\susov\anaconda3\lib\site-packages (from pybaseball) (25.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\susov\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\susov\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\susov\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\susov\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\susov\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\susov\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\susov\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\susov\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\susov\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\susov\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\susov\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\susov\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\susov\anaconda3\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\susov\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: qtconsole in c:\users\susov\anaconda3\lib\site-packages (from jupyter) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\susov\anaconda3\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\susov\anaconda3\lib\site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\susov\anaconda3\lib\site-packages (from jupyter) (6.28.0)
# Requirement already satisfied: ipywidgets in c:\users\susov\anaconda3\lib\site-packages (from jupyter) (7.8.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\susov\anaconda3\lib\site-packages (from notebook) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\susov\anaconda3\lib\site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\susov\anaconda3\lib\site-packages (from notebook) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\susov\anaconda3\lib\site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\susov\anaconda3\lib\site-packages (from notebook) (6.4.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\susov\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.5)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.4.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (75.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\susov\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\susov\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\susov\anaconda3\lib\site-packages (from ipykernel->jupyter) (8.27.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\susov\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\susov\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\susov\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\susov\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\susov\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\susov\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\susov\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\susov\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\susov\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\susov\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\susov\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\susov\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\susov\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\susov\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: pynacl>=1.4.0 in c:\users\susov\anaconda3\lib\site-packages (from pygithub>=1.51->pybaseball) (1.5.0)
# Requirement already satisfied: pyjwt>=2.4.0 in c:\users\susov\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.8.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\susov\anaconda3\lib\site-packages (from pygithub>=1.51->pybaseball) (2.2.3)
# Requirement already satisfied: Deprecated in c:\users\susov\anaconda3\lib\site-packages (from pygithub>=1.51->pybaseball) (1.2.18)
# Requirement already satisfied: six>=1.5 in c:\users\susov\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\susov\anaconda3\lib\site-packages (from requests>=2.18.1->pybaseball) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\susov\anaconda3\lib\site-packages (from requests>=2.18.1->pybaseball) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\susov\anaconda3\lib\site-packages (from requests>=2.18.1->pybaseball) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\susov\anaconda3\lib\site-packages (from tqdm>=4.50.0->pybaseball) (0.4.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\susov\anaconda3\lib\site-packages (from ipywidgets->jupyter) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\susov\anaconda3\lib\site-packages (from ipywidgets->jupyter) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\susov\anaconda3\lib\site-packages (from ipywidgets->jupyter) (1.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-console->jupyter) (3.0.43)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\susov\anaconda3\lib\site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\susov\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\susov\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\susov\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: httpcore==1.* in c:\users\susov\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\susov\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (0.14.0)
# Requirement already satisfied: decorator in c:\users\susov\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\susov\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\susov\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\susov\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\susov\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\susov\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\susov\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\susov\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\susov\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\susov\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\susov\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (43.0.0)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\susov\anaconda3\lib\site-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\susov\anaconda3\lib\site-packages (from Deprecated->pygithub>=1.51->pybaseball) (1.14.1)
# Requirement already satisfied: pycparser in c:\users\susov\anaconda3\lib\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\susov\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\susov\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: executing in c:\users\susov\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\susov\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\susov\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\susov\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.2.3)
# Downloading psycopg2_binary-2.9.10-cp312-cp312-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 9.7 MB/s eta 0:00:00
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, psycopg2-binary, fqdn, isoduration
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 psycopg2-binary-2.9.10 uri-template-1.3.0 webcolors-24.11.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies
import pandas as pd
import pybaseball 
from pybaseball import statcast, cache
import requests 
import glob
import time
import datetime
from datetime import timedelta
import seaborn
import sqlalchemy
import sqlite3
import os

# %%
# cache for pybaseball
cache.enable()

# month breakdown to make api call smoother
months = [
    ('2024-03-28', '2024-04-30'),
    ('2024-05-01', '2024-05-31'),
    ('2024-06-01', '2024-06-30'),
    ('2024-07-01', '2024-07-31'),
    ('2024-08-01', '2024-08-31'),
    ('2024-09-01', '2024-09-30'),
    ('2024-10-01', '2024-10-30')
]

all_data = pd.DataFrame()

# pull data month-by-month and save each to CSV 
for start, end in months:
    print(f"Fetching data from {start} to {end}...")
    try:
        df = statcast(start, end)
        if not df.empty:
            all_data = pd.concat([all_data, df], ignore_index=True)

            # save to CSV with naming convention
            filename = f'statcast_{start}_to_{end}.csv'
            df.to_csv(filename, index=False)
            print(f"Saved: {filename}")
    except Exception as e:
        print(f"Error fetching data from {start} to {end}: {e}")
    time.sleep(1) 

# save the full dataset to a local SQLite database
print("Saving to SQLite database...")
conn = sqlite3.connect('pitch_2024.db')
all_data.to_sql('statcast_2024', conn, if_exists='replace', index=False)
conn.close()
print("✅ Data saved to 'pitch_2024.db' in table 'statcast_2024'.")
# Out:
# Fetching data from 2024-03-28 to 2024-04-30...
# This is a large query, it may take a moment to complete
# 100%|██████████| 34/34 [00:01<00:00, 17.19it/s]
# Saved: statcast_2024-03-28_to_2024-04-30.csv
# Fetching data from 2024-05-01 to 2024-05-31...
# This is a large query, it may take a moment to complete
# 100%|██████████| 31/31 [00:01<00:00, 19.11it/s]
# Saved: statcast_2024-05-01_to_2024-05-31.csv
# Fetching data from 2024-06-01 to 2024-06-30...
# This is a large query, it may take a moment to complete
# 100%|██████████| 30/30 [00:01<00:00, 19.80it/s]
# Saved: statcast_2024-06-01_to_2024-06-30.csv
# Fetching data from 2024-07-01 to 2024-07-31...
# This is a large query, it may take a moment to complete
# 100%|██████████| 31/31 [00:01<00:00, 18.50it/s]
# c:\Users\susov\Anaconda3\Lib\site-packages\pybaseball\statcast.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_data = pd.concat(dataframe_list, axis=0).convert_dtypes(convert_string=False)
# Saved: statcast_2024-07-01_to_2024-07-31.csv
# Fetching data from 2024-08-01 to 2024-08-31...
# This is a large query, it may take a moment to complete
# 100%|██████████| 31/31 [00:01<00:00, 19.76it/s]
# Saved: statcast_2024-08-01_to_2024-08-31.csv
# Fetching data from 2024-09-01 to 2024-09-30...
# This is a large query, it may take a moment to complete
# 100%|██████████| 30/30 [00:01<00:00, 19.05it/s]
# Saved: statcast_2024-09-01_to_2024-09-30.csv
# Fetching data from 2024-10-01 to 2024-10-30...
# This is a large query, it may take a moment to complete
# 100%|██████████| 30/30 [00:01<00:00, 18.69it/s]
# c:\Users\susov\Anaconda3\Lib\site-packages\pybaseball\statcast.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_data = pd.concat(dataframe_list, axis=0).convert_dtypes(convert_string=False)
# Saved: statcast_2024-10-01_to_2024-10-30.csv
# Saving to SQLite database...
# ✅ Data saved to 'pitch_2024.db' in table 'statcast_2024'.

# %%
all_data.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description',
#        ...
#        'n_thruorder_pitcher', 'n_priorpa_thisgame_player_at_bat',
#        'pitcher_days_since_prev_game', 'batter_days_since_prev_game',
#        'pitcher_days_until_next_game', 'batter_days_until_next_game',
#        'api_break_z_with_gravity', 'api_break_x_arm', 'api_break_x_batter_in',
#        'arm_angle'],
#       dtype='object', length=113)

# %%
all_data.head()
# Out:
#   pitch_type  game_date  ...  api_break_x_batter_in  arm_angle
# 0         CH 2024-04-30  ...                   0.77       30.6
# 1         CH 2024-04-30  ...                   0.43       30.0
# 2         CH 2024-04-30  ...                   0.68       34.1
# 3         SL 2024-04-30  ...                  -0.36       46.3
# 4         FF 2024-04-30  ...                   0.66       45.2
#
# [5 rows x 113 columns]

# %%
# Path to your notebook directory containing CSVs
csv_folder = './'

# Path to the data directory for the final combined CSV
output_folder = '../data'

# Find all CSV files in the current notebooks folder
csv_files = glob.glob(os.path.join(csv_folder, '*.csv'))

# Merge CSV files
combined_df = pd.concat((pd.read_csv(file) for file in csv_files), ignore_index=True)

# Output file path
output_file = os.path.join(output_folder, 'mlb_pitch_data_2024.csv')

# Save combined DataFrame to CSV
combined_df.to_csv(output_file, index=False)

print(f'Combined CSV created at {output_file}')
# Out:
# Combined CSV created at ../data\mlb_pitch_data_2024.csv
